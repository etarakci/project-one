# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
ts = TimeSeries(key='LZCTQ8JHH9RXXFMJ',output_format='pandas')
#data, meta_data = ts.get_intraday(symbol='NYSE:URI',interval='1min', outputsize='full')
#print(data)
#data['4. close'].plot()
#plt.title('Intraday TimeSeries')
#plt.show()

# %%
AAPL_data, metadata=ts.get_daily('AAPL',outputsize='full')
AAPL_data.describe()
# Out:
#            1. open      2. high       3. low     4. close     5. volume
# count  5031.000000  5031.000000  5031.000000  5031.000000  5.031000e+03
# mean    174.793354   176.667555   172.759305   174.762821  2.401425e+07
# std     161.146103   162.467489   159.589768   161.055118  1.833573e+07
# min      12.990000    13.190000    12.720000    13.120000  7.025000e+05
# 25%      55.365000    56.925000    54.515000    55.640000  1.036145e+07
# 50%     123.150000   124.880000   121.500000   122.990000  2.056890e+07
# 75%     218.035000   220.665000   215.675000   217.910000  3.226646e+07
# max     702.410000   705.070000   699.570000   702.100000  1.895606e+08

# %%
IBM_data, metadata=ts.get_daily('IBM',outputsize='full')
IBM_data.describe()
# Out:
#            1. open      2. high       3. low     4. close     5. volume
# count  5031.000000  5031.000000  5031.000000  5031.000000  5.031000e+03
# mean    129.663737   130.826195   128.601752   129.735437  6.085299e+06
# std      38.410083    38.475025    38.343155    38.414662  3.310125e+06
# min      54.650000    56.700000    54.010000    55.070000  1.928430e+05
# 25%      94.000000    95.025000    93.055000    94.105000  3.845659e+06
# 50%     126.220000   127.350000   125.060000   126.390000  5.261444e+06
# 75%     159.640000   160.705000   158.500000   159.530000  7.374100e+06
# max     215.380000   215.900000   214.300000   215.800000  4.120730e+07

# %%
AMZN_data, metadata=ts.get_daily('AMZN',outputsize='full')
AMZN_data
# Out:
#             1. open  2. high   3. low  4. close   5. volume
# date
# 2020-04-15  2257.68  2333.37  2245.00   2307.68   6780195.0
# 2020-04-14  2200.47  2292.00  2186.21   2283.32   8087193.0
# 2020-04-13  2040.00  2180.00  2038.00   2168.87   6716709.0
# 2020-04-09  2044.30  2053.00  2017.66   2042.76   4655617.0
# 2020-04-08  2021.00  2044.00  2011.15   2043.00   3977313.0
# ...             ...      ...      ...       ...         ...
# 2000-04-20    53.38    53.69    49.88     52.38   4925300.0
# 2000-04-19    55.31    55.31    51.69     53.44   5373800.0
# 2000-04-18    47.63    56.25    47.13     54.94  10735000.0
# 2000-04-17    45.25    52.00    44.63     47.06  12180900.0
# 2000-04-14    47.88    52.38    40.81     46.88  20074500.0
#
# [5031 rows x 5 columns]

# %%
WMT_data, metadata=ts.get_daily('WMT',outputsize='full')
WMT_data
# Out:
#             1. open  2. high    3. low  4. close   5. volume
# date
# 2020-04-15   129.00   129.88  127.1200    128.76   7426200.0
# 2020-04-14   127.10   129.79  126.0352    129.00  11354477.0
# 2020-04-13   121.27   125.67  121.1700    125.30   8054436.0
# 2020-04-09   118.22   122.87  117.6600    121.80  10942776.0
# 2020-04-08   123.69   123.81  120.5900    121.84   9285834.0
# ...             ...      ...       ...       ...         ...
# 2000-04-20    55.13    57.94   55.1300     57.69   6090400.0
# 2000-04-19    54.13    55.50   53.7500     54.94   6255300.0
# 2000-04-18    54.00    56.31   53.1300     53.88   7661200.0
# 2000-04-17    55.13    56.38   51.7500     54.00   9660500.0
# 2000-04-14    58.00    58.94   55.0000     55.00   9372700.0
#
# [5031 rows x 5 columns]

# %%
AAL_data, metadata=ts.get_daily('AAL',outputsize='full')
AAL_data
# Out:
#             1. open  2. high  3. low  4. close    5. volume
# date
# 2020-04-15    12.52    12.69   11.39    12.290  122904361.0
# 2020-04-14    12.22    12.60   11.75    11.945   68039491.0
# 2020-04-13    12.90    12.95   11.25    11.560   73385533.0
# 2020-04-09    12.64    13.40   11.82    12.510  117592821.0
# 2020-04-08    10.91    11.40   10.50    11.330   82718687.0
# ...             ...      ...     ...       ...          ...
# 2005-10-03    20.90    21.75   20.90    21.500    2836193.0
# 2005-09-30    20.26    21.05   20.18    21.010    8373458.0
# 2005-09-29    20.40    20.58   20.10    20.210    2890617.0
# 2005-09-28    19.30    20.53   19.20    20.500   15409920.0
# 2005-09-27    21.05    21.40   19.10    19.300    2576944.0
#
# [3662 rows x 5 columns]

# %%
ANTM_data, metadata=ts.get_daily('ANTM',outputsize='full')
ANTM_data
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2020-04-15   249.15  254.350  245.11    250.47  2424142.0
# 2020-04-14   245.76  254.190  245.24    252.01  2145550.0
# 2020-04-13   240.78  243.490  237.65    240.53  1036639.0
# 2020-04-09   240.94  248.055  239.93    242.46  2191205.0
# 2020-04-08   227.15  248.830  226.41    247.02  2415201.0
# ...             ...      ...     ...       ...        ...
# 2001-01-08   100.80  104.000  100.30    102.60   439800.0
# 2001-01-05    97.88  102.400   96.25    100.20  1086700.0
# 2001-01-04   107.00  109.300   95.50     96.81  1982000.0
# 2001-01-03   107.10  111.500  106.50    106.80   844800.0
# 2001-01-02   115.30  115.800  105.60    106.60   617000.0
#
# [4851 rows x 5 columns]

# %%
PFE_data, metadata=ts.get_daily('PFE',outputsize='full')
PFE_data
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# date
# 2020-04-15    36.06  36.2300  35.580     35.97  20107997.0
# 2020-04-14    35.93  36.6300  35.335     36.44  20721415.0
# 2020-04-13    35.96  35.9800  34.720     35.14  17327516.0
# 2020-04-09    35.03  35.7673  34.850     35.39  29074991.0
# 2020-04-08    33.99  34.8000  33.440     34.60  24200145.0
# ...             ...      ...     ...       ...         ...
# 2000-04-20    42.13  42.1300  40.750     41.50  10864700.0
# 2000-04-19    39.69  42.5000  39.380     41.81  20078700.0
# 2000-04-18    38.00  39.6300  38.000     39.56  14219400.0
# 2000-04-17    37.25  38.8800  37.000     38.00  13853300.0
# 2000-04-14    38.94  39.0600  36.880     37.94  13730900.0
#
# [5031 rows x 5 columns]

# %%
df['WMT']=WMT_data['4. close']

# %%
df=pd.DataFrame()

# %%
df['AAPL']=AAPL_data['4. close']
df
# Out:
#               AAPL
# date
# 2020-04-15  284.43
# 2020-04-14  287.05
# 2020-04-13  273.25
# 2020-04-09  267.99
# 2020-04-08  266.07
# ...            ...
# 2000-04-20  118.87
# 2000-04-19  121.12
# 2000-04-18  126.87
# 2000-04-17  123.87
# 2000-04-14  111.87
#
# [5031 rows x 1 columns]

# %%
df.set_index(AAPL_data.index, inplace=True)
df.head()
# Out:
#               AAPL
# date
# 2020-04-15  284.43
# 2020-04-14  287.05
# 2020-04-13  273.25
# 2020-04-09  267.99
# 2020-04-08  266.07

# %%
AAL_data.describe()
# Out:
#            1. open      2. high       3. low     4. close     5. volume
# count  3662.000000  3662.000000  3662.000000  3662.000000  3.662000e+03
# mean     27.056296    27.541009    26.541177    27.029740  1.419766e+07
# std      16.729339    16.927438    16.520430    16.727951  1.362279e+07
# min       1.810000     2.030000     1.450000     1.760000  3.713140e+05
# 25%       9.632500     9.900000     9.380000     9.620000  6.176228e+06
# 50%      29.715000    30.325000    29.120000    29.690000  1.020496e+07
# 75%      41.595000    42.207500    40.964350    41.597500  1.767232e+07
# max      62.700000    63.270000    62.000000    62.950000  2.107003e+08

# %%
df['AAL']=AAL_data['4. close']

# %%
df['WMT']=WMT_data['4. close']

# %%
df['AMZN']=AMZN_data['4. close']

# %%
df['IBM']=IBM_data['4. close']

# %%
df['PFE']=PFE_data['4. close']

# %%
df['ANTM']=ANTM_data['4. close']

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3662 entries, 2020-04-15 to 2005-09-27
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3662 non-null   float64
#  1   AAL     3662 non-null   float64
#  2   AMZN    3662 non-null   float64
#  3   IBM     3662 non-null   float64
#  4   PFE     3662 non-null   float64
#  5   ANTM    3662 non-null   float64
#  6   WMT     3662 non-null   float64
# dtypes: float64(7)
# memory usage: 228.9 KB

# %%
df[['AAPL','AAL','AMZN','IBM','WMT','PFE','ANTM']].plot(figsize=(16, 9))

# %%
df.to_csv('stock2.csv')

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from functools import reduce
import datetime as dt

# %%
#read CSV files
df1=pd.read_csv("data-APZBu.csv") #Nasdaq_data
df2=pd.read_csv("data-EKHTG.csv")#Dow_data
df3=pd.read_csv("data-ULLTa.csv") #S&P500_data

# compile the list of dataframes you want to merge
data_frames = [df1, df2, df3]

#merge our data frames
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Date'],
                                            how='outer'), data_frames)
#merge our data frames
#combined_data=pd.merge(Nasdaq_data,Dow_data,SP500_data, on="left")

df_merged
# Out:
#         Date  Close_x   Close_y    Close
# 0   4/8/2020  8090.90  23433.57  2749.98
# 1   4/7/2020  7887.26  22653.86  2659.41
# 2   4/6/2020  7913.24  22679.99  2663.68
# 3   4/3/2020  7373.08  21052.53  2488.65
# 4   4/2/2020  7487.31  21413.44  2526.90
# ..       ...      ...       ...      ...
# 63  1/8/2020  9129.24  28745.09  3253.05
# 64  1/7/2020  9068.58  28583.68  3237.18
# 65  1/6/2020  9071.47  28703.38  3246.28
# 66  1/3/2020  9020.77  28634.88  3234.85
# 67  1/2/2020  9092.19  28868.80  3257.85
#
# [68 rows x 4 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 0 to 67
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     68 non-null     object
#  1   Close_x  68 non-null     float64
#  2   Close_y  68 non-null     float64
#  3   Close    68 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 2.7+ KB

# %%
df_merged
# Out:
#         Date  Close_x   Close_y    Close
# 0   4/8/2020  8090.90  23433.57  2749.98
# 1   4/7/2020  7887.26  22653.86  2659.41
# 2   4/6/2020  7913.24  22679.99  2663.68
# 3   4/3/2020  7373.08  21052.53  2488.65
# 4   4/2/2020  7487.31  21413.44  2526.90
# ..       ...      ...       ...      ...
# 63  1/8/2020  9129.24  28745.09  3253.05
# 64  1/7/2020  9068.58  28583.68  3237.18
# 65  1/6/2020  9071.47  28703.38  3246.28
# 66  1/3/2020  9020.77  28634.88  3234.85
# 67  1/2/2020  9092.19  28868.80  3257.85
#
# [68 rows x 4 columns]

# %%
# Plot all the close prices
df_merged['Date']=pd.to_datetime (df_merged ['Date'])
df_merged.set_index('Date', inplace=True)
df_merged.plot( figsize=(10, 7))
# Show the legend
plt.legend()
# Define the label for the title of the figure
plt.title(" Close Price Index", fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Date', fontsize=14)
# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
